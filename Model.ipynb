# %% [markdown]
# # Credit Card Fraud Detection
#
# ## Table of Contents
#
# 1. [Introduction](#Introduction)
# 2. [Package Installation](#Package-installation)
# 3. [Importing Libraries](#Importing-Library)
# 4. [Importing Dataset](#Importing-dataset)
# 5. [Data Cleansing](#Data-Cleansing)
# 6. [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# 7. [Univariate Analysis](#Univariate-Analysis)
# 8. [Multivariate Analysis](#Multivariate-Analysis)
# 9. [Analyzing Fraud Distribution Across Categories](#Analyzing-Fraud-distribution-Across-Categories)
# 10. [Analyzing Fraud Patterns in Specific Categories](#Analyzing-Fraud-Patterns-in-Specific-Categories)
# 11. [Feature Engineering](#Feature-Engineering)
# 12. [Scaling](#Scaling)
# 13. [Categorical Encoding](#Categorical-Encoding)
# 14. [UnderSampling](#UnderSampling)
# 15. [Feature Importance](#Feature-Importance)
# 16. [Preparing Test Data](#Preparing-test-Data)
# 17. [Preparing Validation Data](#Preparing-Validation-Data)
# 18. [Training the Model](#Training-the-model)
# 19. [Hyperparameter Tuning](#Hyperparameter-Tuning)
# 20. [Saving the Model](#Saving-the-model)
# 21. [Conclusion](#Conclusion)
#
# ## Introduction
# In this project, we aim to detect fraudulent credit card transactions using machine learning techniques. The dataset contains information about various transactions, and our goal is to build a model that can accurately identify fraudulent activities.
#
# We'll start by loading the dataset, exploring its structure, and performing necessary preprocessing steps such as handling missing values and encoding categorical features.
# For this, we are going to use a Credit Card Transactions dataset, with the objective to identify fraudulent transactions. First we'll cover the setup, by checking the data, then we'll do an Exploratory Data Analysis (EDA), to identify possible patterns and insights to use as features in our model, aswell as identify needed transformations. After that, we'll do the feature engineering, by using scaling and categorical encoding. Then we'll cover Undersampling and its importance, and then check the feature importances. Finally but not least important, we'll prepare our validation and test datasets to train, tune and evaluate our models!

# %% [markdown]
# ## Package Installation
#
# To run this notebook, you need to install the following Python packages. You can install them by executing the following commands:

# %%
# %pip install numpy==1.23.3 --no-cache-dir
# Out:
# Requirement already satisfied: numpy==1.23.3 in c:\users\amals\anaconda3\lib\site-packages (1.23.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install missingno
# %pip install category_encoders
# %pip install Boruta
# %pip install lightgbm
# %pip install scikit-optimize
# %pip install --upgrade scikit-learn
# %pip install --upgrade imbalanced-learn
# Out:
# Requirement already satisfied: missingno in c:\users\amals\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\amals\anaconda3\lib\site-packages (from missingno) (1.23.3)
# Requirement already satisfied: matplotlib in c:\users\amals\anaconda3\lib\site-packages (from missingno) (3.7.1)
# Requirement already satisfied: scipy in c:\users\amals\anaconda3\lib\site-packages (from missingno) (1.10.1)
# Requirement already satisfied: seaborn in c:\users\amals\anaconda3\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\amals\anaconda3\lib\site-packages (from matplotlib->missingno) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\amals\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\amals\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\amals\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\amals\anaconda3\lib\site-packages (from matplotlib->missingno) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\amals\anaconda3\lib\site-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\amals\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\amals\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\amals\anaconda3\lib\site-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amals\anaconda3\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\amals\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: category_encoders in c:\users\amals\anaconda3\lib\site-packages (2.6.3)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\amals\anaconda3\lib\site-packages (from category_encoders) (1.23.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\amals\anaconda3\lib\site-packages (from category_encoders) (1.3.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\amals\anaconda3\lib\site-packages (from category_encoders) (1.10.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\amals\anaconda3\lib\site-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\amals\anaconda3\lib\site-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\amals\anaconda3\lib\site-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\amals\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amals\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2022.7)
# Requirement already satisfied: six in c:\users\amals\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\amals\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\amals\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\amals\anaconda3\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (23.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Boruta in c:\users\amals\anaconda3\lib\site-packages (0.3)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\amals\anaconda3\lib\site-packages (from Boruta) (1.23.3)
# Requirement already satisfied: scikit-learn>=0.17.1 in c:\users\amals\anaconda3\lib\site-packages (from Boruta) (1.3.2)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\amals\anaconda3\lib\site-packages (from Boruta) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\amals\anaconda3\lib\site-packages (from scikit-learn>=0.17.1->Boruta) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\amals\anaconda3\lib\site-packages (from scikit-learn>=0.17.1->Boruta) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lightgbm in c:\users\amals\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: numpy in c:\users\amals\anaconda3\lib\site-packages (from lightgbm) (1.23.3)
# Requirement already satisfied: scipy in c:\users\amals\anaconda3\lib\site-packages (from lightgbm) (1.10.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-optimize in c:\users\amals\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\amals\anaconda3\lib\site-packages (from scikit-optimize) (1.2.0)
# Requirement already satisfied: pyaml>=16.9 in c:\users\amals\anaconda3\lib\site-packages (from scikit-optimize) (23.9.7)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\amals\anaconda3\lib\site-packages (from scikit-optimize) (1.23.3)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\amals\anaconda3\lib\site-packages (from scikit-optimize) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\amals\anaconda3\lib\site-packages (from scikit-optimize) (1.3.2)
# Requirement already satisfied: PyYAML in c:\users\amals\anaconda3\lib\site-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\amals\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->scikit-optimize) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\amals\anaconda3\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\amals\anaconda3\lib\site-packages (from scikit-learn) (1.23.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\amals\anaconda3\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\amals\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\amals\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imbalanced-learn in c:\users\amals\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\amals\anaconda3\lib\site-packages (from imbalanced-learn) (1.23.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\amals\anaconda3\lib\site-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\amals\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\amals\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\amals\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importing Libraries

# %% [markdown]
# Importing necessary libraries for Sampling Methods,Feature Engineering,Feature Selection,Hyperparameter Tuning and Model Evaluation.

# %%
#Basic libraries
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import math
pd.set_option('display.max_columns', None)
plt.style.use('ggplot')

#Sampling methods
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler

#feature engineering
import datetime as dt
import category_encoders as ce
from sklearn.preprocessing import MinMaxScaler

#Feature Selection
from boruta import BorutaPy

#Models
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier

#Hyperparameter tuning
from skopt import gp_minimize

#Model evaluation
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import classification_report
from sklearn import metrics
import scipy.stats as stats
from scipy.stats import skew

#Model Saving
import joblib

# %% [markdown]
# ## Importing Dataset
#
# We load the credit card fraud dataset using Pandas from a CSV file, creating the 'train' DataFrame.
# The display format for floating-point numbers is set to two decimal places.

# %%
train = pd.read_csv("fraudTrain.csv", index_col=0)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# Note : Update the filepath of the train dataset accordingly.

# %% [markdown]
# ## Data Cleansing

# %% [markdown]
# First we'll have a look at our data.

# %%
train.head(3)
# Out:
#   trans_date_trans_time            cc_num                         merchant  \
# 0   2019-01-01 00:00:18  2703186189652095       fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322  fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661             fraud_Lind-Buckridge
#
#         category    amt      first     last gender  \
# 0       misc_net   4.97   Jennifer    Banks      F
# 1    grocery_pos 107.23  Stephanie     Gill      F
# 2  entertainment 220.11     Edward  Sanchez      M
#
#                          street            city state    zip   lat    long  \
# 0                561 Perry Cove  Moravian Falls    NC  28654 36.08  -81.18
# 1  43039 Riley Greens Suite 393          Orient    WA  99160 48.89 -118.21
# 2      594 White Dale Suite 530      Malad City    ID  83252 42.18 -112.26
#
#    city_pop                                job         dob  \
# 0      3495          Psychologist, counselling  1988-03-09
# 1       149  Special educational needs teacher  1978-06-21
# 2      4154        Nature conservation officer  1962-01-19
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018      36.01      -82.05
# 1  1f76529f8574734946361c461b024d99  1325376044      49.16     -118.19
# 2  a1a22d70485983eac12b5b88dad1cf95  1325376051      43.15     -112.15
#
#    is_fraud
# 0         0
# 1         0
# 2         0

# %%
train.shape
# Out:
# (1296675, 22)

# %% [markdown]
# The 'msno.matrix(train)' command generates a matrix plot, highlighting missing values to aid in our exploratory data analysis.

# %%
msno.matrix(train);

# %%
train.isna().sum()
# Out:
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %% [markdown]
# As we can see, there is no missing values!

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# To gain insights into the credit card fraud dataset, we perform exploratory data analysis (EDA). Utilizing the 'describe()' function, we generate descriptive statistics, including measures of central tendency, dispersion, and shape of the distribution for each numerical feature in the 'train' DataFrame.

# %%
train.describe().T
# Out:
#                   count                       mean  \
# cc_num     1,296,675.00 417,192,042,079,726,656.00
# amt        1,296,675.00                      70.35
# zip        1,296,675.00                  48,800.67
# lat        1,296,675.00                      38.54
# long       1,296,675.00                     -90.23
# city_pop   1,296,675.00                  88,824.44
# unix_time  1,296,675.00           1,349,243,636.73
# merch_lat  1,296,675.00                      38.54
# merch_long 1,296,675.00                     -90.23
# is_fraud   1,296,675.00                       0.01
#
#                                     std               min  \
# cc_num     1,308,806,447,000,789,248.00 60,416,207,185.00
# amt                              160.32              1.00
# zip                           26,893.22          1,257.00
# lat                                5.08             20.03
# long                              13.76           -165.67
# city_pop                     301,956.36             23.00
# unix_time                 12,841,278.42  1,325,376,018.00
# merch_lat                          5.11             19.03
# merch_long                        13.77           -166.67
# is_fraud                           0.08              0.00
#
#                               25%                      50%  \
# cc_num     180,042,946,491,150.00 3,521,417,320,836,166.00
# amt                          9.65                    47.52
# zip                     26,237.00                48,174.00
# lat                         34.62                    39.35
# long                       -96.80                   -87.48
# city_pop                   743.00                 2,456.00
# unix_time        1,338,750,742.50         1,349,249,747.00
# merch_lat                   34.73                    39.37
# merch_long                 -96.90                   -87.44
# is_fraud                     0.00                     0.00
#
#                                 75%                          max
# cc_num     4,642,255,475,285,942.00 4,992,346,398,065,154,048.00
# amt                           83.14                    28,948.90
# zip                       72,042.00                    99,783.00
# lat                           41.94                        66.69
# long                         -80.16                       -67.95
# city_pop                  20,328.00                 2,906,700.00
# unix_time          1,359,385,375.50             1,371,816,817.00
# merch_lat                     41.96                        67.51
# merch_long                   -80.24                       -66.95
# is_fraud                       0.00                         1.00

# %%
train["amt"].describe()
# Out:
# count   1,296,675.00
# mean           70.35
# std           160.32
# min             1.00
# 25%             9.65
# 50%            47.52
# 75%            83.14
# max        28,948.90
# Name: amt, dtype: float64

# %%
train.dtypes.value_counts().plot(kind='bar', color="grey");

# %%
train.dtypes
# Out:
# trans_date_trans_time     object
# cc_num                     int64
# merchant                  object
# category                  object
# amt                      float64
# first                     object
# last                      object
# gender                    object
# street                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# trans_num                 object
# unix_time                  int64
# merch_lat                float64
# merch_long               float64
# is_fraud                   int64
# dtype: object

# %% [markdown]
# Since there are many categorical features, we'll likely use categorical encoding in our analysis.

# %% [markdown]
# ## Univariate Analysis - Fraud Proportion in Transactions
#
# To visualize the proportion of fraud in transactions, a donut chart is created. The 'is_fraud' column is used to count occurrences of fraud (Yes) and non-fraud (No) transactions. The donut chart displays the percentage of fraud transactions relative to the total, providing a quick overview of fraud distribution.

# %% [markdown]
# Lets check the target imbalance!

# %%
donut = train["is_fraud"].value_counts().reset_index()

labels = ["No", "Yes"]
explode = (0, 0)

fig, ax = plt.subplots(dpi=120, figsize=(8, 4))
plt.pie(donut["is_fraud"],
        labels=donut["is_fraud"],
        autopct="%1.1f%%",
        pctdistance=0.8,
        explode=explode)

centre_circle = plt.Circle((0.0, 0.0), 0.5, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title("Fraud proportion in Transactions")
plt.legend(labels, loc="center", frameon=False)
plt.show();

# %% [markdown]
# Our dataset shows a significant imbalance between fraud and non-fraud transactions. Since this imbalance can affect model performance, we're considering techniques like oversampling or undersampling to address it during the model building process.

# %% [markdown]
# Let's check the distribution of the amount ("amt") feature.

# %%
sns.kdeplot(train["amt"], fill=True);

# %% [markdown]
# To improve the clarity of our graph, we're addressing distortion caused by higher values of the 'amount' feature. The graph will now display transactions within the 0-99% range of the 'amount' values, providing a more focused view.

# %%
p99 = train["amt"].quantile(0.99)
sns.kdeplot(x="amt", data=train[train["amt"] <= p99], fill=True);

# %% [markdown]
# We're investigating if there's any noticeable pattern or relationship between the target variable ('is_fraud') and the transaction amount. This analysis aims to uncover insights into how fraudulent transactions may relate to the transaction amounts.

# %% [markdown]
# ## Multivariate Analysis

# %%
p99 = train["amt"].quantile(0.99)
sns.histplot(x="amt", hue="is_fraud", bins=30,
             stat="probability", data=train[train["amt"] <= p99],
             common_norm=False);

# %% [markdown]
# Notice that the probability distribution behaves differently for each value of "is_fraud".

# %% [markdown]
# ## Analyzing Fraud Distribution Across Categories
# We can expand this analysis to each transaction category:

# %%
categories = train['category'].unique()

num_plots = len(categories)
num_rows = math.isqrt(num_plots)
num_cols = math.ceil(num_plots / num_rows)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(
    5*num_cols, 5*num_rows), sharex=True)

for i, category in enumerate(categories):

    row = i // num_cols
    col = i % num_cols

    data_category = train[train['category'] == category]

    if num_rows == 1 and num_cols == 1:
        ax = axes
    elif num_rows == 1 or num_cols == 1:
        ax = axes[i]
    else:
        ax = axes[row, col]

    sns.histplot(x='amt', data=data_category[data_category['amt'] <= p99],
                 hue='is_fraud', stat='probability',
                 common_norm=False, bins=30, ax=ax)

    ax.set_ylabel('Percentage in Each Type')
    ax.set_xlabel('Transaction Amount in USD')
    ax.set_title(f'{category}')
    ax.legend(title='Type', labels=['Fraud', 'Not Fraud'])

plt.tight_layout()

plt.show();

# %% [markdown]
# ## Analyzing Fraud Patterns in Specific Categories
#
# To investigate fraud patterns in specific transaction categories, histograms are plotted for 'shopping_net' and 'shopping_pos'. The histograms display the distribution of transaction amounts for each category, highlighting the percentage of fraud and non-fraud transactions, providing insights into potential fraudulent activity in these specific categories.

# %%
categories_of_interest = ['shopping_net', 'shopping_pos']

plt.figure(figsize=(15, 6))

for i, category_of_interest in enumerate(categories_of_interest, 1):
    plt.subplot(1, 2, i)

    data_category_of_interest = train[train['category'] == category_of_interest]

    sns.histplot(
        x='amt',
        data=data_category_of_interest,
        hue='is_fraud',
        stat='probability',
        common_norm=False,
        bins=30
    )

    plt.ylabel('Percentage in Each Type')
    plt.xlabel('Transaction Amount in USD')
    plt.title(f'Histogram for {category_of_interest} Transactions')
    plt.legend(title='Type', labels=['Not Fraud', 'Fraud'])

plt.tight_layout()
plt.show()

# %% [markdown]
# To understand which categories are more prone to fraud, we calculate the distribution of categories for normal and fraudulent transactions. The resulting dataframe, 'non_fraud_vs_fraud,' quantifies the difference in distribution between normal and fraudulent transactions for each category. The 'fraud_level' column indicates the extent to which a category is associated with fraud, offering insights into potential fraudulent patterns in specific transaction categories.

# %%
# non_fraud
non_fraud = train[train['is_fraud'] == 0]['category'].value_counts(
    normalize=True).to_frame().reset_index()
non_fraud.columns = ['category', 'not_fraud_percentual_vs_total']

# fraud
fraud = train[train['is_fraud'] == 1]['category'].value_counts(
    normalize=True).to_frame().reset_index()
fraud.columns = ['category', 'fraud_percentage_vs_total']

# merging two dataframes and calculating "fraud level"
non_fraud_vs_fraud = non_fraud.merge(fraud, on='category')
non_fraud_vs_fraud['fraud_level'] = non_fraud_vs_fraud['fraud_percentage_vs_total'] - \
    non_fraud_vs_fraud['not_fraud_percentual_vs_total']

non_fraud_vs_fraud
# Out:
#           category  not_fraud_percentual_vs_total  fraud_percentage_vs_total  \
# 0    gas_transport                           0.10                       0.08
# 1             home                           0.10                       0.03
# 2      grocery_pos                           0.09                       0.23
# 3     shopping_pos                           0.09                       0.11
# 4        kids_pets                           0.09                       0.03
# 5     shopping_net                           0.07                       0.23
# 6    entertainment                           0.07                       0.03
# 7      food_dining                           0.07                       0.02
# 8    personal_care                           0.07                       0.03
# 9   health_fitness                           0.07                       0.02
# 10        misc_pos                           0.06                       0.03
# 11        misc_net                           0.05                       0.12
# 12     grocery_net                           0.04                       0.02
# 13          travel                           0.03                       0.02
#
#     fraud_level
# 0         -0.02
# 1         -0.07
# 2          0.14
# 3          0.02
# 4         -0.06
# 5          0.15
# 6         -0.04
# 7         -0.05
# 8         -0.04
# 9         -0.05
# 10        -0.03
# 11         0.07
# 12        -0.02
# 13        -0.02

# %% [markdown]
# To visually represent the fraud level across transaction categories, a bar plot is created. The 'fraud_level' metric, indicating the percentage difference in the likelihood of fraud for each category, is used. The plot highlights which categories are more common for fraudulent transactions, providing a clear overview of the relative fraud levels in different transaction categories.

# %%
custom_palette = sns.color_palette("flare")
ax = sns.barplot(y='category', x='fraud_level',
                 data=non_fraud_vs_fraud.sort_values('fraud_level', ascending=False), palette=custom_palette)
ax.set_xlabel('Percentage Difference')
ax.set_ylabel('Transaction Category')
plt.title('Fraud Level');

# %% [markdown]
# As shown above, some categories are more propicious to have frauds than others.

# %% [markdown]
# Let's see how the Age distribution behaves for fraud and non-fraud transactions.

# %%
train['age'] = dt.date.today().year-pd.to_datetime(train['dob']).dt.year
ax = sns.kdeplot(x='age', data=train, hue='is_fraud', common_norm=False)
ax.set_xlabel('Credit Card Holder Age')
ax.set_ylabel('Density')
plt.xticks(np.arange(0, 110, 10))
plt.title('Age Distribution')
plt.legend(title='Type', labels=['Fraud', 'Not Fraud']);

# %% [markdown]
# We can observe that in non-fraudulent transactions, there is a peak around 35 years and 40 years, and another one around 50 years. On the other hand, in fraudulent operations, we observe a smoother distribution, with peaks around 35 years and in the range of 50 years to 55 years.

# %% [markdown]
# Let's analyze if the time in a day has any impact.

# %%
train['hour'] = pd.to_datetime(train['trans_date_trans_time']).dt.hour
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6), sharey=True)
ax1 = sns.histplot(x='hour', data=train[train["is_fraud"] == 0],
                   stat="density", bins=24, ax=ax1)
ax2 = sns.histplot(x='hour', data=train[train["is_fraud"] == 1],
                   stat="density", bins=24, ax=ax2, color="blue")
ax1.set_title("Normal")
ax2.set_title("Fraud")
ax1.set_xticks(np.arange(1, 24))
ax2.set_xticks(np.arange(1, 24));

# %% [markdown]
# As we can see, there is a clear pattern when it comes to hour in the day. Fraudulent payments happens more frequently around midnight than in normal transactions.

# %% [markdown]
# Let's do the same for months!

# %%
train['month'] = pd.to_datetime(train['trans_date_trans_time']).dt.month
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6), sharey=True)
ax1 = sns.histplot(x='month', data=train[train["is_fraud"] == 0],
                   stat="density", bins=12, ax=ax1)
ax2 = sns.histplot(x='month', data=train[train["is_fraud"] == 1],
                   stat="density", bins=12, ax=ax2, color="blue")
ax1.set_title("Normal")
ax2.set_title("Fraud")
ax1.set_xticks(np.arange(1, 13))
ax2.set_xticks(np.arange(1, 13));

# %% [markdown]
# > As we saw above, this problem has a very imbalanced target class. We have only 0.6% of event occurrence. That means if we do a blind guess, by telling that every transaction is not fraud, we will still get a 99.4% accuracy!
#
# > That happens because we will still be getting right all the transactions that are not fraud, which stands for 99.4% of the dataset.
#
# > For that reason, it is very dangerous to look at only accuracy in a model. We have plenty of others good metrics to look at, besides accuracy.
#
# > Some of them are: Precision, Recall, F1-score, ROC Curves and AUC!

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# First, let's drop some columns that has duplicated or not useful information

# %%
train.drop(columns=["merchant", "first", "last", "street",
           "unix_time", "trans_num"], inplace=True)

# %%
train.head(2)
# Out:
#   trans_date_trans_time            cc_num     category    amt gender  \
# 0   2019-01-01 00:00:18  2703186189652095     misc_net   4.97      F
# 1   2019-01-01 00:00:44      630423337322  grocery_pos 107.23      F
#
#              city state    zip   lat    long  city_pop  \
# 0  Moravian Falls    NC  28654 36.08  -81.18      3495
# 1          Orient    WA  99160 48.89 -118.21       149
#
#                                  job         dob  merch_lat  merch_long  \
# 0          Psychologist, counselling  1988-03-09      36.01      -82.05
# 1  Special educational needs teacher  1978-06-21      49.16     -118.19
#
#    is_fraud  age  hour  month
# 0         0   35     0      1
# 1         0   45     0      1

# %% [markdown]
# We saw that the "amt" category has very little spacing between small numbers and large spacing between high numbers. Because of that, we are going to use non logarithm scaling, that increases the distance between small values and reduces de spacing between large ones.

# %% [markdown]
# ## Scaling

# %%
train["amt_log"] = np.log1p(train["amt"])
sns.kdeplot(train["amt_log"], fill=True);

# %% [markdown]
# Let's check the normality of the "amt" feature compared to its transformation "amt_log".

# %%
def check_normality(feature):
    plt.figure(figsize=(8, 8))
    ax1 = plt.subplot(1, 1, 1)
    stats.probplot(train[feature], dist=stats.norm, plot=ax1)
    ax1.set_title(f'{feature} Q-Q plot', fontsize=20)
    sns.despine()

    mean = train[feature].mean()
    std = train[feature].std()
    skew = train[feature].skew()
    print(f'{feature} - mean: {mean:.2f}, std: {std:.2f}, skew: {skew:.2f}')

# %%
check_normality("amt");
# Out:
# amt - mean: 70.35, std: 160.32, skew: 42.28

# %%
check_normality("amt_log");
# Out:
# amt_log - mean: 3.53, std: 1.29, skew: -0.30

# %% [markdown]
# We can see that with the logarithm scaling, the skewness has improved a lot.

# %% [markdown]
# ## Categorical Encoding

# %% [markdown]
# Since we have a binary target and categorical variables with high cardinality, we are going to use the WOE (Weight of Evidence) encoder for the features: category, state, city and job.

# %%
def apply_woe(train, columns, target_col):
    woe = ce.WOEEncoder()

    for col in columns:
        X = train[col]
        y = train[target_col]

        new_col_name = f"{col}_WOE"
        train[new_col_name] = woe.fit_transform(X, y)

    return train


columns_to_encode = ["category", "state", "city", "job"]
target_column = "is_fraud"

train = apply_woe(train, columns_to_encode, target_column)

# %% [markdown]
# As for gender category, we can simply encode it by using dummies.

# %%
gender_mapping = {"F": 0, "M": 1}

train["gender_binary"] = train["gender"].map(gender_mapping)

# %% [markdown]
# We can encode the cc_num (credit card number) variable as well, by counting their frequencies in the database and them dividing them into classes, so we can classify the cards that are used a lot, and the ones that are not used often in the database.

# %%
freq_enc = (train.groupby("cc_num").size())
freq_enc.sort_values(ascending=True)
train["cc_num_frequency"] = train["cc_num"].apply(lambda x: freq_enc[x])

# %%
sns.histplot(train["cc_num_frequency"], bins=6);

# %%
intervals = [600, 1200, 1800, 2400, 3000, 3600]


def classify_frequency(freq):
    for i, c in enumerate(intervals):
        if freq <= c:
            return i


train["cc_num_frequency_classification"] = train["cc_num_frequency"].apply(
    classify_frequency)

# %% [markdown]
# Let's see if the distributions are different among the frequency classes for fraudulent and non-fraudulent transactions.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6), sharey=True)
ax1 = sns.histplot(x='cc_num_frequency_classification', data=train[train["is_fraud"] == 0],
                   stat="density", bins=6, ax=ax1)
ax2 = sns.histplot(x='cc_num_frequency_classification', data=train[train["is_fraud"] == 1],
                   stat="density", bins=6, ax=ax2, color="blue")
ax1.set_title("Normal")
ax2.set_title("Fraud");

# %% [markdown]
# As we can see, there is a clear pattern happening. Frauds are more propitious to happen in credit cards with less use (new ones), and when it comes to normal transactions, it follows a normal distribution.

# %% [markdown]
# # Undersampling

# %% [markdown]
# As we saw, our data is very imbalanced. Because of that, we are going to use Undersampling in our favor. The method that we are going to use is the RandomUnderSampler.

# %%
X = train.drop(columns=["is_fraud"])
y = train["is_fraud"]

# %%
rus = RandomUnderSampler(sampling_strategy=0.1, random_state=23)

# %%
X_undersampled, y_undersampled = rus.fit_resample(X, y)

# %% [markdown]
# Let's check our proportion after the Undersampling.

# %%
donut = y_undersampled.value_counts().reset_index()

labels = ["No", "Yes"]
explode = (0, 0)

fig, ax = plt.subplots(dpi=120, figsize=(8, 4))
plt.pie(donut["is_fraud"],
        labels=donut["is_fraud"],
        autopct="%1.1f%%",
        pctdistance=0.8,
        explode=explode)

centre_circle = plt.Circle((0.0, 0.0), 0.5, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title("Fraud Proportion with Undersampling")
plt.legend(labels, loc="center", frameon=False)
plt.show();

# %% [markdown]
# # Feature Importance

# %% [markdown]
# First, we are going to generate two random vectors to help us compare the feature importances (If a feature has less importance than a random vector, we can suspect that the feature is not good for the model).

# %%
X_undersampled["random_feat_1"] = np.random.randint(
    0, 100, size=len(X_undersampled))
X_undersampled["random_feat_2"] = np.random.randint(
    0, 500, size=len(X_undersampled))

# %%
X_train = X_undersampled.drop(columns=["trans_date_trans_time",
                                       "city", "state", "category", "gender", "dob", "job", "cc_num", "amt"])

y_train = y_undersampled

# %%
X_train.head()
# Out:
#           zip   lat    long  city_pop  merch_lat  merch_long  age  hour  \
# 118515  77566 29.04  -95.44     28739      29.24      -95.43   24     5
# 598857  12460 42.41  -74.15       277      41.56      -74.09   52     7
# 59238   98304 46.75 -121.99       759      46.60     -122.18   67    18
# 710180  31042 32.81  -83.17      1841      33.09      -84.14   48     5
# 6204    99160 48.89 -118.21       149      48.08     -119.14   45    23
#
#         month  amt_log  category_WOE  state_WOE  city_WOE  job_WOE  \
# 118515      3     3.89         -0.21      -0.14      0.14     0.35
# 598857      9     4.65          0.90       0.14      0.20     0.70
# 59238       2     2.39         -0.70      -0.12      0.77     0.11
# 710180     10     3.63         -0.61      -0.03      0.00    -0.23
# 6204        1     1.42          1.12      -0.12     -3.03    -0.90
#
#         gender_binary  cc_num_frequency  cc_num_frequency_classification  \
# 118515              1              2556                                4
# 598857              1              1548                                2
# 59238               0              1040                                1
# 710180              1              1548                                2
# 6204                0              3030                                5
#
#         random_feat_1  random_feat_2
# 118515             10            493
# 598857             68             65
# 59238               7            185
# 710180             72            296
# 6204               72            316

# %% [markdown]
# Let's use Boruta algorithm and random forests feature importances to identify which features we are going to use in our model.

# %%
X_train.head()
# Out:
#           zip   lat    long  city_pop  merch_lat  merch_long  age  hour  \
# 118515  77566 29.04  -95.44     28739      29.24      -95.43   24     5
# 598857  12460 42.41  -74.15       277      41.56      -74.09   52     7
# 59238   98304 46.75 -121.99       759      46.60     -122.18   67    18
# 710180  31042 32.81  -83.17      1841      33.09      -84.14   48     5
# 6204    99160 48.89 -118.21       149      48.08     -119.14   45    23
#
#         month  amt_log  category_WOE  state_WOE  city_WOE  job_WOE  \
# 118515      3     3.89         -0.21      -0.14      0.14     0.35
# 598857      9     4.65          0.90       0.14      0.20     0.70
# 59238       2     2.39         -0.70      -0.12      0.77     0.11
# 710180     10     3.63         -0.61      -0.03      0.00    -0.23
# 6204        1     1.42          1.12      -0.12     -3.03    -0.90
#
#         gender_binary  cc_num_frequency  cc_num_frequency_classification  \
# 118515              1              2556                                4
# 598857              1              1548                                2
# 59238               0              1040                                1
# 710180              1              1548                                2
# 6204                0              3030                                5
#
#         random_feat_1  random_feat_2
# 118515             10            493
# 598857             68             65
# 59238               7            185
# 710180             72            296
# 6204               72            316

# %%
rf = RandomForestClassifier(random_state=23, max_depth=5)
feat_selector = BorutaPy(rf, n_estimators="auto", random_state=999)
result_boruta = feat_selector.fit(X_train.values, y_train)
accept = X_train.columns[feat_selector.support_].to_list()
irresolution = X_train.columns[feat_selector.support_weak_].to_list()

print("Features selected:")
list(accept)
# Out:
# Features selected:
# ['zip',
#  'lat',
#  'long',
#  'city_pop',
#  'merch_lat',
#  'merch_long',
#  'age',
#  'hour',
#  'month',
#  'amt_log',
#  'category_WOE',
#  'state_WOE',
#  'city_WOE',
#  'job_WOE',
#  'gender_binary',
#  'cc_num_frequency',
#  'cc_num_frequency_classification']

# %% [markdown]
# Now let's check feature importance with Random Forest.

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
importances = rf.feature_importances_

# %%
forest_importances = pd.Series(importances, index=X_train.columns)

fig, ax = plt.subplots(figsize=(12, 5))
forest_importances.sort_values(ascending=False).plot.bar(ax=ax)
ax.set_ylabel("Feature Importance")
fig.tight_layout();

# %% [markdown]
# Now we proceed to select our features. Since "cc_num_frequency" and "cc_num_frequency_classification" is the same information, we are going to drop the less important.

# %%
X_train.drop(columns=["gender_binary", "state_WOE", "zip", "long", "lat",
                      "city_pop", "month", "cc_num_frequency_classification",
                      "random_feat_1", "random_feat_2", "merch_long"], inplace=True)

# %%
X_train.head()
# Out:
#         merch_lat  age  hour  amt_log  category_WOE  city_WOE  job_WOE  \
# 118515      29.24   24     5     3.89         -0.21      0.14     0.35
# 598857      41.56   52     7     4.65          0.90      0.20     0.70
# 59238       46.60   67    18     2.39         -0.70      0.77     0.11
# 710180      33.09   48     5     3.63         -0.61      0.00    -0.23
# 6204        48.08   45    23     1.42          1.12     -3.03    -0.90
#
#         cc_num_frequency
# 118515              2556
# 598857              1548
# 59238               1040
# 710180              1548
# 6204                3030

# %% [markdown]
# Finally, this is the features that are entering the model.

# %% [markdown]
# # Preparing test data

# %% [markdown]
# Let's apply the same transformations on test data.

# %%
test = pd.read_csv("fraudTest.csv", index_col=0)


test['age'] = dt.date.today().year-pd.to_datetime(test['dob']).dt.year
test['hour'] = pd.to_datetime(test['trans_date_trans_time']).dt.hour
test['month'] = pd.to_datetime(test['trans_date_trans_time']).dt.month

test.drop(columns=["merchant", "first", "last", "street",
                   "unix_time", "trans_num"], inplace=True)

test["amt_log"] = np.log1p(test["amt"])

test = apply_woe(test, columns_to_encode, target_column)

test["gender_binary"] = test["gender"].map(gender_mapping)

freq_enc_test = (test.groupby("cc_num").size())
freq_enc_test.sort_values(ascending=True)
test["cc_num_frequency"] = test["cc_num"].apply(lambda x: freq_enc_test[x])
test["cc_num_frequency_classification"] = test["cc_num_frequency"].apply(
    classify_frequency)

X_test = test.drop(columns=["trans_date_trans_time",
                            "city", "state", "category", "gender", "dob", "job", "cc_num", "amt", "is_fraud"])

y_test = test["is_fraud"]

X_test.drop(columns=["gender_binary", "state_WOE", "zip", "long", "lat",
                     "city_pop", "month", "cc_num_frequency_classification", "merch_long"], inplace=True)

# %% [markdown]
# # Preparing validation data

# %% [markdown]
# In order to tune our hyperparameters, we are going to separate our training set into training and validation.

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# # Training the model

# %% [markdown]
# First, let's create a function to help us evaluate our models.

# %%
def evaluate_model(target, predicted, y_score, normalize_matrix= None):
    accuracy = metrics.accuracy_score(target, predicted)
    precision = metrics.precision_score(target, predicted)
    recall = metrics.recall_score(target, predicted)
    f1 = f1_score(target, predicted)
    auc = metrics.roc_auc_score(target, y_score)

    confusion_matrix = metrics.confusion_matrix(
        target, predicted, normalize=normalize_matrix)
    cm_display = metrics.ConfusionMatrixDisplay(
        confusion_matrix=confusion_matrix, display_labels=[False, True])
    cm_display.plot()
    plt.grid(False)
    plt.show()

    fpr, tpr, threshold = roc_curve(target, y_score)
    plt.plot(fpr, tpr, label="Model", c="blue")
    plt.plot([0, 1], [0, 1], linestyle="--", c="yellow")
    plt.title("ROC Curve")
    plt.legend()
    plt.show()

    print("Accuracy", accuracy.round(2))
    print("Precision:", precision.round(2))
    print("Recall:", recall.round(2))
    print("F1 Score", f1.round(2))
    print("AUC:", auc)
    return None

# %% [markdown]
# Now we'll run some tests on which models potentially runs best for our model!

# %%
rf = RandomForestClassifier(random_state=23)
knn = KNeighborsClassifier()
gboost = GradientBoostingClassifier(random_state=23)
lgbm = LGBMClassifier(random_state=23)

# %% [markdown]
# Let's see the results of the models without any tuning.

# %%
#random forest

rf.fit(X_train, y_train)

y_pred_train = rf.predict(X_train)
y_score_train = rf.predict_proba(X_train)[:,1]

y_pred_test = rf.predict(X_test)
y_score_test = rf.predict_proba(X_test)[:,1]

# %%
#training metrics
evaluate_model(y_train, y_pred_train, y_score_train)
# Out:
# Accuracy 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score 1.0
# AUC: 1.0

# %%
#test metrics
evaluate_model(y_test, y_pred_test, y_score_test)
# Out:
# Accuracy 0.92
# Precision: 0.04
# Recall: 0.92
# F1 Score 0.08
# AUC: 0.9844063458691312

# %%
#k-nearest neighbors

knn.fit(X_train, y_train)

y_pred_train = knn.predict(X_train)
y_score_train = knn.predict_proba(X_train)[:,1]

y_pred_test = knn.predict(X_test)
y_score_test = knn.predict_proba(X_test)[:,1]

# %%
#training metrics
evaluate_model(y_train, y_pred_train, y_score_train)
# Out:
# Accuracy 0.96
# Precision: 0.92
# Recall: 0.6
# F1 Score 0.73
# AUC: 0.9844013197155983

# %%
#test metrics
evaluate_model(y_test, y_pred_test, y_score_test)
# Out:
# Accuracy 0.82
# Precision: 0.01
# Recall: 0.5
# F1 Score 0.02
# AUC: 0.70793927879864

# %%
#gradient boosting

gboost.fit(X_train, y_train)

y_pred_train = gboost.predict(X_train)
y_score_train = gboost.predict_proba(X_train)[:,1]

y_pred_test = gboost.predict(X_test)
y_score_test = gboost.predict_proba(X_test)[:,1]

# %%
#training metrics
evaluate_model(y_train, y_pred_train, y_score_train)
# Out:
# Accuracy 0.98
# Precision: 0.96
# Recall: 0.86
# F1 Score 0.91
# AUC: 0.9933870937929041

# %%
#test metrics
evaluate_model(y_test, y_pred_test, y_score_test)
# Out:
# Accuracy 0.98
# Precision: 0.13
# Recall: 0.91
# F1 Score 0.23
# AUC: 0.9873503632336237

# %%
#LightGBM

lgbm.fit(X_train, y_train)

y_pred_train = lgbm.predict(X_train)
y_score_train = lgbm.predict_proba(X_train)[:,1]

y_pred_test = lgbm.predict(X_test)
y_score_test = lgbm.predict_proba(X_test)[:,1]
# Out:
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000969 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535

# %%
#training metrics
evaluate_model(y_train, y_pred_train, y_score_train)
# Out:
# Accuracy 0.99
# Precision: 0.98
# Recall: 0.96
# F1 Score 0.97
# AUC: 0.9996799675946321

# %%
#test metrics
evaluate_model(y_test, y_pred_test, y_score_test)
# Out:
# Accuracy 0.99
# Precision: 0.34
# Recall: 0.9
# F1 Score 0.49
# AUC: 0.9949717758195035

# %% [markdown]
# LightGBM and GradientBoost performed really well on our model. So let's proceed to tune their hyperparameters!

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# Let's create a function that optimizes our desired metric. Since we can't use accuracy because of the imbalance, we are going to optimize F1 score!

# %%
def tune_lgbm(params):
    learning_rate = params[0]
    num_leaves = params[1]
    min_child_samples = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
    
    print(params)
    
    mdl = LGBMClassifier(learning_rate= learning_rate,
                         num_leaves= num_leaves,
                         min_child_samples= min_child_samples,
                         subsample= subsample,
                         colsample_bytree= colsample_bytree,
                         random_state=23, subsample_freq=1,
                         n_estimators=200)
    
    mdl.fit(X_train, y_train)

    y_pred = mdl.predict(X_valid)
    
    return -metrics.f1_score(y_valid, y_pred)

# %%
space = [(1e-3, 1e-1, "log-uniform"), #learning_rate
        (2,128), #num_leaves
        (1,100), #min_child_samples
        (0.05, 1.0), #subsample
        (0.1, 1.0)] #colsample_bytree

# %%
results = gp_minimize(tune_lgbm, space, random_state=23,
                      verbose=1, n_calls=100, n_random_starts=20)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [0.021786840314037433, 25, 78, 0.5952129636704409, 0.4977223159193984]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002309 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.5718
# Function value obtained: -0.8980
# Current minimum: -0.8980
# Iteration No: 2 started. Evaluating function at random point.
# [0.002333405878539521, 15, 23, 0.8416721432755412, 0.4840888306663812]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000327 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.4282
# Function value obtained: -0.0000
# Current minimum: -0.8980
# Iteration No: 3 started. Evaluating function at random point.
# [0.03229577569301482, 128, 1, 0.9771571003653318, 0.4772091051979678]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000223 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 1.0834
# Function value obtained: -0.9212
# Current minimum: -0.9212
# Iteration No: 4 started. Evaluating function at random point.
# [0.023073573532330794, 97, 58, 0.4251939328278432, 0.5316165472583452]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001233 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.9184
# Function value obtained: -0.9079
# Current minimum: -0.9212
# Iteration No: 5 started. Evaluating function at random point.
# [0.006051746127837253, 86, 76, 0.8419972065467979, 0.2549656996678612]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001399 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.7421
# Function value obtained: -0.3711
# Current minimum: -0.9212
# Iteration No: 6 started. Evaluating function at random point.
# [0.002656481807063609, 112, 44, 0.8822740555343906, 0.5235455926200475]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001404 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.8368
# Function value obtained: -0.0000
# Current minimum: -0.9212
# Iteration No: 7 started. Evaluating function at random point.
# [0.0040258332878283344, 99, 2, 0.6924311479424573, 0.5245127854479901]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001308 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.8562
# Function value obtained: -0.3533
# Current minimum: -0.9212
# Iteration No: 8 started. Evaluating function at random point.
# [0.018549433296399687, 118, 14, 0.8474268408162635, 0.7343737507584486]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001451 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.9978
# Function value obtained: -0.9428
# Current minimum: -0.9428
# Iteration No: 9 started. Evaluating function at random point.
# [0.08625494325676673, 116, 30, 0.19006457678478134, 0.22712950048241895]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000317 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.9167
# Function value obtained: -0.9000
# Current minimum: -0.9428
# Iteration No: 10 started. Evaluating function at random point.
# [0.08102099942702626, 2, 30, 0.5143317692574327, 0.12694363379062684]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000170 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.2441
# Function value obtained: -0.8167
# Current minimum: -0.9428
# Iteration No: 11 started. Evaluating function at random point.
# [0.057128022638658495, 16, 71, 0.07583992943347748, 0.27080380150042427]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000214 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 0.3941
# Function value obtained: -0.8728
# Current minimum: -0.9428
# Iteration No: 12 started. Evaluating function at random point.
# [0.03486657777966428, 100, 97, 0.44192276574439365, 0.8162320161324087]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001541 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 0.9982
# Function value obtained: -0.9425
# Current minimum: -0.9428
# Iteration No: 13 started. Evaluating function at random point.
# [0.008658084409573406, 58, 38, 0.8321146941571493, 0.6083701115580573]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001419 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.6606
# Function value obtained: -0.8978
# Current minimum: -0.9428
# Iteration No: 14 started. Evaluating function at random point.
# [0.001905276119571006, 124, 4, 0.9320245178595369, 0.5701125925690917]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001522 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.9503
# Function value obtained: -0.0000
# Current minimum: -0.9428
# Iteration No: 15 started. Evaluating function at random point.
# [0.0012232261771304956, 90, 26, 0.9896321698747691, 0.8049776126486301]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001648 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 0.8687
# Function value obtained: -0.0000
# Current minimum: -0.9428
# Iteration No: 16 started. Evaluating function at random point.
# [0.009862316793216386, 76, 43, 0.4179023762062301, 0.540112363686712]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000338 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.8092
# Function value obtained: -0.8551
# Current minimum: -0.9428
# Iteration No: 17 started. Evaluating function at random point.
# [0.006635618878971444, 39, 65, 0.8783639707243251, 0.9425786827249363]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000923 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 0.6052
# Function value obtained: -0.8950
# Current minimum: -0.9428
# Iteration No: 18 started. Evaluating function at random point.
# [0.02968839867649073, 39, 78, 0.3533920777309588, 0.18996983827644906]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001365 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 0.5641
# Function value obtained: -0.8601
# Current minimum: -0.9428
# Iteration No: 19 started. Evaluating function at random point.
# [0.012686319817940137, 95, 31, 0.522808461366737, 0.8660566106869689]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001510 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.8179
# Function value obtained: -0.9350
# Current minimum: -0.9428
# Iteration No: 20 started. Evaluating function at random point.
# [0.03285017570611721, 44, 55, 0.6828570873392136, 0.9817007003658578]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000454 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 1.1471
# Function value obtained: -0.9459
# Current minimum: -0.9459
# Iteration No: 21 started. Searching for the next optimal point.
# [0.009252237290857333, 25, 24, 1.0, 0.8366298453847523]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001490 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.8715
# Function value obtained: -0.8999
# Current minimum: -0.9459
# Iteration No: 22 started. Searching for the next optimal point.
# [0.0814055041277998, 128, 1, 0.05, 0.8120886197616238]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001606 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 1.0288
# Function value obtained: -0.2315
# Current minimum: -0.9459
# Iteration No: 23 started. Searching for the next optimal point.
# [0.02931688525239458, 72, 90, 0.615361071146015, 0.8950847862405914]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001496 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 1.1633
# Function value obtained: -0.9438
# Current minimum: -0.9459
# Iteration No: 24 started. Searching for the next optimal point.
# [0.01759104125141187, 2, 8, 0.05, 1.0]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001900 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.6818
# Function value obtained: -0.7912
# Current minimum: -0.9459
# Iteration No: 25 started. Searching for the next optimal point.
# [0.013173113274805996, 128, 100, 0.05, 0.6949869008361621]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001395 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 1.6652
# Function value obtained: -0.8537
# Current minimum: -0.9502
# Iteration No: 85 started. Searching for the next optimal point.
# [0.03406757059121638, 128, 100, 0.993986680384712, 0.7944745987511128]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001581 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 1.9515
# Function value obtained: -0.9450
# Current minimum: -0.9502
# Iteration No: 86 started. Searching for the next optimal point.
# [0.1, 128, 1, 1.0, 0.2673455116749621]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000608 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 1.9348
# Function value obtained: -0.9076
# Current minimum: -0.9502
# Iteration No: 87 started. Searching for the next optimal point.
# [0.04152469838336993, 48, 1, 1.0, 1.0]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000406 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 1.6750
# Function value obtained: -0.9514
# Current minimum: -0.9514
# Iteration No: 88 started. Searching for the next optimal point.
# [0.025288625904794162, 121, 1, 0.4949880139055331, 0.9769728760009878]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001668 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 2.0848
# Function value obtained: -0.9462
# Current minimum: -0.9514
# Iteration No: 89 started. Searching for the next optimal point.
# [0.024609918647182056, 113, 1, 0.7720898512531581, 0.9548476498009064]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001568 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 2.1821
# Function value obtained: -0.9480
# Current minimum: -0.9514
# Iteration No: 90 started. Searching for the next optimal point.
# [0.037584249769053696, 56, 34, 1.0, 1.0]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000441 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 1.7655
# Function value obtained: -0.9498
# Current minimum: -0.9514
# Iteration No: 91 started. Searching for the next optimal point.
# [0.04688961891768339, 128, 1, 1.0, 0.7529232617136838]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001329 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 2.1600
# Function value obtained: -0.9492
# Current minimum: -0.9514
# Iteration No: 92 started. Searching for the next optimal point.
# [0.03737076261220211, 38, 1, 0.3231588241239963, 0.38092415765518706]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000236 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 1.7074
# Function value obtained: -0.9019
# Current minimum: -0.9514
# Iteration No: 93 started. Searching for the next optimal point.
# [0.016132697707919915, 106, 1, 0.6302223534250657, 1.0]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001535 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 2.2055
# Function value obtained: -0.9444
# Current minimum: -0.9514
# Iteration No: 94 started. Searching for the next optimal point.
# [0.05215839545020651, 2, 90, 1.0, 1.0]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001755 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 1.5365
# Function value obtained: -0.8012
# Current minimum: -0.9514
# Iteration No: 95 started. Searching for the next optimal point.
# [0.04015827311007665, 80, 1, 0.8283574245705726, 1.0]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001679 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 2.1787
# Function value obtained: -0.9505
# Current minimum: -0.9514
# Iteration No: 96 started. Searching for the next optimal point.
# [0.04310451399051039, 128, 1, 1.0, 0.8887431880735375]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001640 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 2.3531
# Function value obtained: -0.9490
# Current minimum: -0.9514
# Iteration No: 97 started. Searching for the next optimal point.
# [0.1, 128, 100, 0.5715176334290112, 0.3128585892932332]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000233 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 2.4611
# Function value obtained: -0.9208
# Current minimum: -0.9514
# Iteration No: 98 started. Searching for the next optimal point.
# [0.02029264195779753, 128, 1, 1.0, 0.5535182290647237]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000229 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 2.3316
# Function value obtained: -0.9111
# Current minimum: -0.9514
# Iteration No: 99 started. Searching for the next optimal point.
# [0.009486889109159378, 128, 1, 0.6653255562279942, 0.9169648692904555]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001537 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 2.4903
# Function value obtained: -0.9356
# Current minimum: -0.9514
# Iteration No: 100 started. Searching for the next optimal point.
# [0.012461381284821214, 128, 1, 0.6541437895638329, 1.0]
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001517 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 2.4176
# Function value obtained: -0.9430
# Current minimum: -0.9514

# %%
params = results.x
params
# Out:
# [0.04152469838336993, 48, 1, 1.0, 1.0]

# %%
learning_rate = params[0]
num_leaves = params[1]
min_child_samples = params[2]
subsample = params[3]
colsample_bytree = params[4]

# %%
#LightGBM
lgbm = LGBMClassifier(learning_rate= learning_rate,
                      num_leaves= num_leaves,
                      min_child_samples= min_child_samples,
                      subsample= subsample,
                      colsample_bytree= colsample_bytree,
                      random_state=23, subsample_freq=1,
                      n_estimators=200)

lgbm.fit(X_train, y_train)

y_pred_train = lgbm.predict(X_train)
y_score_train = lgbm.predict_proba(X_train)[:,1]

y_pred_test = lgbm.predict(X_test)
y_score_test = lgbm.predict_proba(X_test)[:,1]
# Out:
# [LightGBM] [Info] Number of positive: 6005, number of negative: 60047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001727 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1389
# [LightGBM] [Info] Number of data points in the train set: 66052, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.090913 -> initscore=-2.302535
# [LightGBM] [Info] Start training from score -2.302535

# %%
evaluate_model(y_test, y_pred_test, y_score_test, normalize_matrix="true")
# Out:
# Accuracy 0.99
# Precision: 0.27
# Recall: 0.9
# F1 Score 0.41
# AUC: 0.9922603656006959

# %% [markdown]
# ## Saving the Model

# %% [markdown]
# After finding optimal Model we have to save the model

# %%
model_filename = 'lgbm_model.joblib'
joblib.dump(lgbm, model_filename)
# Out:
# ['lgbm_model.joblib']

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this notebook, we conducted a comprehensive analysis and built a model for credit card fraud detection. Here are some key takeaways:
#
# >- **Data Exploration:** Explored the dataset, identified patterns, and gained insights into fraud distribution across different categories.
#
# >- **Feature Engineering:** Engineered features to enhance the model's predictive power.
#
# >- **Model Training:** Trained a model using the prepared data, tuned hyperparameters, and evaluated its performance.
#
# > In this problem, it is crucial to look at other metrics besides accuracy. As we saw, accuracy is one of the worst metrics for this problem, because of the natural imbalance of the dataset.
#
# > Since our event is related to fraud transactions, we assume the worst cenarios was getting high false negatives (transactions that we identify as non-frauds and ended up being fraudulents). Hence, we used an aproach to consider the recall metric being the most important for the model.
#
# > Also, the precision of the model is very sensitive, because of the target imbalance. As you can see, only 0.71% or normal transactions were false positives, and it dropped the precision to 33%. That is because a small percentage of normal transactions if predicted wrong, means a high number of events compared to the fraud events in dataset.
#
# > The best approach to this problem would be having a way to calculate the mean cost of each false positive and false negative. This way, we could approach this tradeoff with better understanding of how much false positives and false negatives costs for the company.
